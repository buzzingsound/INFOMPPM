# %%
import pandas as pd
import glob
import string
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords

# %%
# Uncomment if running for the first time

html_files = glob.glob('../data/ABC/*/*.html')
html_files[:5]
# Out:
# ['../data/ABC/documentary/hannah-gadsby-s-nakedy-nudes.html',
#  '../data/ABC/documentary/that-christmas-video-RN1911H029S00.html',
#  '../data/ABC/documentary/wimbledon-kidnapping.html',
#  '../data/ABC/documentary/exposed-the-ghost-train-fire.html',
#  '../data/ABC/documentary/muster-dogs.html']

# %%
print(123)
# Out:
# 123

# %%
# Uncomment if running for the first time

### Extract metadata from html files

raw_data = []

for file in html_files:
    category_name = file.split('/')[3] # extract category name from folder name

    soup = BeautifulSoup(open(file, 'rb'), 'html.parser')
    content = {}

    # extract title of article
    if soup.find('meta',  attrs={'property': 'og:title'}):
      title = soup.find('meta',  attrs={'property': 'og:title'})['content']
    else:
      title = ''

    # extract description of article
    if soup.find('meta',  attrs={'name': 'description'}):
      description = soup.find('meta',  attrs={'name': 'description'})['content']
    else:
      description = ''

    # extract article url
    if soup.find('meta',  attrs={'property': 'og:url'}):
      url = soup.find('meta',  attrs={'property': 'og:url'})['content']
    else:
      url = ''

    # extract image from the article
    if soup.find('meta', attrs={'property':'og:image'}):
        thumbnail = soup.find('meta', attrs={'property':'og:image'})['content']
    else:
        thumbnail = ''

    # put metadata extracts to a dictionary
    content = {
        'title': title,
        'description': description,
        'category_name': category_name,
        'thumbnail':thumbnail,
        'url': url
    }

    # append the article to the data
    raw_data.append(content)

raw_data
# Out:
# [{'title': "Hannah Gadsby's Nakedy Nudes",
#   'description': 'Hannah Gadsby unravels the apparently simple practice of recreating our own nude human form. Taking a close look at one of the most enduring subjects in western art history.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1603H_5c3ec3155375e_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/hannah-gadsby-s-nakedy-nudes'},
#  {'title': 'That Christmas',
#   'description': 'Eleven poignant, funny and powerful stories about Christmas like no other, told by the people who lived through them. Some of the storytellers are familiar faces, some are new.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1911H029S00_5fbf352f4954e_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/that-christmas/video/RN1911H029S00'},
#  {'title': 'The Wimbledon Kidnapping',
#   'description': "Exploring the mysterious disappearance of Muriel McKay, the UK's first kidnapping case and one of the most infamous cases of mistaken identity.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3047A_6189d6d76e77e.jpg',
#   'url': 'https://iview.abc.net.au/show/wimbledon-kidnapping'},
#  {'title': 'EXPOSED: The Ghost Train Fire',
#   'description': "Exposing the truths behind the mystery of the Ghost Train Fire at Sydney's iconic Luna Park, award-winning journalist Caro Meldrum-Hanna returns for a ground-breaking three-part investigation.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ns/NS2077H_6035a4e2b8df7_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/exposed-the-ghost-train-fire'},
#  {'title': 'Muster Dogs',
#   'description': 'Five graziers from across Australia are given five Kelpie puppies from the same litter and set with the challenge of transforming these uniquely Australian dogs into champion muster dogs.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rf/RF2003H_61b169765d01e.jpg',
#   'url': 'https://iview.abc.net.au/show/muster-dogs'},
#  {'title': 'The Detectives',
#   'description': "Follows Manchester's homicide detectives over the course of a year as they try to unravel complex cases in dramatic real time.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3122A_6170bee533656_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/detectives'},
#  {'title': 'Blue Water Empire',
#   'description': 'A dramatised-documentary series giving a unique insight into the compelling history of the Torres Strait Islands, told through key stories by the men and women of the region.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ip/IP1505Q_5d09b5345eb62_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/blue-water-empire'},
#  {'title': "Laura's Choice",
#   'description': 'Laura Henkel is eccentric, outspoken, feisty and 90 years old. She has decided she wants to end her life on her own terms, and she asks her daughter Cathy and granddaughter Sam, both filmmakers, to make a film about it.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/dc/DC1917W_603da45a307d2.jpg',
#   'url': 'https://iview.abc.net.au/show/laura-s-choice'},
#  {'title': "David Attenborough's Great Barrier Reef",
#   'description': 'Almost sixty years after his first visit to the Great Barrier Reef, David Attenborough embarks on a personal journey of discovery to understand how the Reef was created and meets the animals that call it home.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW0220A_6123381823364_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-great-barrier-reef'},
#  {'title': "The Making Of David Attenborough's Conquest Of The Skies",
#   'description': "Witness the incredible innovations and technical advancements that went into The Making Of David Attenborough's TV series Conquest Of The Skies.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX9705A001S0054ebbdfac9aee6.67710749_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/making-of-david-attenborough-s-conquest-of-the-skies/video/ZX9705A001S00'},
#  {'title': 'Christmas Sounds Better This Year',
#   'description': 'Every Christmas the same old songs are played so we got some talented people to compose new ones. In this heart-warming musical adventure we celebrate the Australian Christmas spirit at its very best.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1811H028S00_5de5e5f7b6f81.jpg',
#   'url': 'https://iview.abc.net.au/show/christmas-sounds-better-this-year/video/RN1811H028S00'},
#  {'title': 'The Lost Aviator',
#   'description': 'Set in the Golden Age of Aviation, Andrew Lancaster follows the life and times of his great uncle, Captain Bill Lancaster, and uncovers a fascinating tale of adventure, obsession, love and a sensational murder trial. (2014)',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2779A001S00_609214194a2df_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/lost-aviator/video/ZW2779A001S00'},
#  {'title': 'Greta Thunberg: A Year To Change The World',
#   'description': 'Climate activist Greta Thunberg takes a year off school to explore the science of global warming and challenge world leaders, calling for action on climate change.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2761A_6111e0194b04a_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/greta-thunberg-a-year-to-change-the-world'},
#  {'title': "Old People's Home For 4 Year Olds",
#   'description': 'A unique social experiment that brings together elderly people in a retirement community with a group of 4-year-olds. Could this encounter between young and old help transform the lives of the elderly?',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1803H_5d536795d8237_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/old-people-s-home-for-4-year-olds'},
#  {'title': "Australia Remastered: Nature's Great Divide",
#   'description': 'The hard line that separates the natural worlds of Asia from Australia is the leaping off point for amazing wild stories. The strong currents along the Wallace Line creates parallel narratives of fascinating differences.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1955H_619c51e12d498_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/australia-remastered-nature-s-great-divide'},
#  {'title': 'Just Between Us',
#   'description': 'In this bold new series, each episode is a collection of themed short stories told by the people who lived them. Familiar and not so familiar faces reveal secrets and truths, and intimate family stories are shared.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/fr/FR2036H_6170b3e480f16_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/just-between-us'},
#  {'title': "China's Artful Dissident",
#   'description': "Follows a Chinese political artist in exile, on a personal challenge to stop the Communist regime's whitewashing of history and abuse of human rights, and in the process, risking his family's freedom.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1811H001S00_607d68ddcce19_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/china-s-artful-dissident/video/AC1811H001S00'},
#  {'title': 'One Shot: An Image And An Attitude',
#   'description': 'Internationally renowned surf photographer Russell Ord has built a reputation for capturing incredible images of surfers on massive waves. Russell is a man on a quest - the one perfect shot.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1524W001S00_58cb584479a22_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/one-shot-an-image-and-an-attitude/video/AC1524W001S00'},
#  {'title': "David Attenborough's Global Adventure",
#   'description': 'From the deep oceans in a state-of-the-art submarine on the Great Barrier Reef, to the ancient rainforests of Borneo, David Attenborough embarks on a unique natural history adventure across the globe and through time.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3049A_612597104ecf7_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-global-adventure'},
#  {'title': 'Australian Story',
#   'description': "Putting the 'real' back into reality TV, the award-winning series with no narrator and no agendas, just authentic stories told in people's own words. For 25 years we have been telling the stories of extraordinary Australians.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/nc/NC2102Q_61f72309d6d18_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/australian-story'},
#  {'title': 'Australia Remastered: Forces of Nature',
#   'description': 'Hosted and narrated by Aaron Pedersen, this series explores the apocalyptic natural forces that nature inflicts upon Australia. As the climate changes, Australian wildlife must keep pace to survive.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1843H_61e63b061838f.jpg',
#   'url': 'https://iview.abc.net.au/show/australia-remastered-forces-of-nature'},
#  {'title': 'The Great Australian Bee Challenge',
#   'description': 'In this two-part special, host Paul West challenges four families to successfully keep a honeybee hive, bringing these everyday Australians up close with the latest science about bee brains, communication and behaviour.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/sq/SQ1802H_5c3d31486f90b.jpg',
#   'url': 'https://iview.abc.net.au/show/great-australian-bee-challenge'},
#  {'title': 'The Art of Remembrance',
#   'description': "Nate Byrne explores the role of paintings and sketches that represent the experiences of our service personnel and how visual art can help us to learn more about Australia's military history.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rf/RF2009H001S00_6082437f5c064_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/art-of-remembrance/video/RF2009H001S00'},
#  {'title': 'Our Dementia Choir',
#   'description': 'Actor Vicky McClure recruits people with dementia to form a choir. And experts from medicine, music therapy and performance nurture and rehearse with them. This is a story where personal achievements meet breaking science.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2655A_60137ae420d77_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/our-dementia-choir'},
#  {'title': "Louis Theroux: Surviving America's Most Hated Family",
#   'description': "Louis Theroux revisits the hugely controversial Westboro Baptist Church to investigate how its founder's death has affected current and former members.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2588A001S00_60d170f7c224d.jpg',
#   'url': 'https://iview.abc.net.au/show/louis-theroux-surviving-america-s-most-hated-family/video/ZW2588A001S00'},
#  {'title': "A Stargazer's Guide To The Cosmos (2018)",
#   'description': 'Charismatic astronomer Greg Quicke (aka Space Gandalf) takes us on the ultimate guided tour of the southern sky, revealing unseen connections between the everyday world around us and the stars above.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1704W001S00_5af538aa693cc_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/stargazer-s-guide-to-the-cosmos-2018/video/DO1704W001S00'},
#  {'title': 'The Rise Of The Murdoch Dynasty',
#   'description': "The incredible story of Rupert Murdoch's influence on world events and the dramatic personal battle for power at the heart of his own family.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2447A_5f5709f95bb23.jpg',
#   'url': 'https://iview.abc.net.au/show/rise-of-the-murdoch-dynasty'},
#  {'title': 'Bronwyn Oliver: The Shadows Within',
#   'description': "This intimate documentary follows the journey of Bronwyn Oliver, a working-class girl from the country who became one of Australia's most influential contemporary sculptors.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC2014H001S00_6152912688858.jpg',
#   'url': 'https://iview.abc.net.au/show/bronwyn-oliver-the-shadows-within/video/AC2014H001S00'},
#  {'title': 'The Crown and Us: The Story of The Royals in Australia',
#   'description': 'The Crown is part of who we were and who we are - and despite the secrets, scandals and questions of relevance, our reverence for the British Royals remains as strong as ever. Why is that? And will it ever change?',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1715H_5c7c6b6cb641e_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/crown-and-us-the-story-of-the-royals-in-australia'},
#  {'title': 'Back To Earth: Stargazing Live',
#   'description': "Following each night's Stargazing Live broadcast on ABC, Back to Earth allows viewers to journey deeper into the ideas explored on the main show and ask questions of both Brian Cox and a panel of expert scientists.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/dc/DC1716H_5b0748dec66a1_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/back-to-earth-stargazing-live'},
#  {'title': 'Making Of Micro Monsters with David Attenborough',
#   'description': "A thrilling voyage into a realm that's close to us yet quite inaccessible to the naked eye and confusing to human sensibilities - the strange, weird and wonderful world of bugs.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX9706A001S00_5fd9a1bc72d65_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/making-of-micro-monsters-with-david-attenborough/video/ZX9706A001S00'},
#  {'title': 'Midsomer Murders: 20th Anniversary Special',
#   'description': 'Presented by John Nettles, the original DCI Barnaby, this anniversary special features stars past and present discussing the peculiar quirks of the delightful yet deadly county.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2985A001S00_610a1bbe68516_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/midsomer-murders-20th-anniversary-special/video/ZW2985A001S00'},
#  {'title': "The Making of David Attenborough's Great Barrier Reef",
#   'description': "Go behind-the-scenes of David Attenborough's landmark series Great Barrier Reef as he returns with the latest technology to explore this natural wonder 60 years after his first visit.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW0221A001S00570aeed58eaf18.80892225_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/making-of-david-attenborough-s-great-barrier-reef/video/ZW0221A001S00'},
#  {'title': "The Queen's Green Planet",
#   'description': "Her Majesty Queen Elizabeth talks to Sir David Attenborough about her ambitious legacy project the Queen's Commonwealth Canopy, aiming to create a global network of protected forests in all 53 Commonwealth countries.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1520A001S00_5fed52800938c_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/queen-s-green-planet/video/ZW1520A001S00'},
#  {'title': 'War Stories',
#   'description': 'The team from Landline bring you some of the best reporting on stories of war, survival and remembering.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ra/RA2104Q_6082501b1e45a_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/war-stories'},
#  {'title': "Making Of David Attenborough's Natural History Museum Alive",
#   'description': "Take a behind-the-scenes look at the making of the documentary David Attenborough's Natural History Museum Alive.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2598A001S00_606299d30abb6_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/making-of-david-attenborough-s-natural-history-museum-alive/video/ZW2598A001S00'},
#  {'title': 'Inside The Met',
#   'description': 'Go behind the scenes as the largest art museum in the Americas plans its 150th anniversary, responds to the coronavirus pandemic and calls for social justice.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2601A_60ff9cf4d47b8.jpg',
#   'url': 'https://iview.abc.net.au/show/inside-the-met'},
#  {'title': 'Songs Of Praise: Faith And Hospitality',
#   'description': "Katherine Jenkins visits L'Abri fellowship in Hampshire to explore Christian faith and hospitality. She finds out about L'Abri's history and meets a family from Australia who are volunteering there.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3234A001S00_61f8aa6ad38d9.jpg',
#   'url': 'https://iview.abc.net.au/show/songs-of-praise-faith-and-hospitality/video/ZW3234A001S00'},
#  {'title': 'Dr Kwane: The Street Vet',
#   'description': 'Dr Kwane is on a mission to help the pets and people of America who need it the most  the homeless. From treating simple ailments on the side of the road, to major emergencies.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2973A_60b5ed2495396_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/dr-kwane-the-street-vet'},
#  {'title': 'Hitting Home With Sarah Ferguson',
#   'description': 'Award-winning journalist Sarah Ferguson spends five months on the frontline of our national domestic violence crisis.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1409H_5c3fbe21e5688_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/hitting-home-with-sarah-ferguson'},
#  {'title': 'Making Child Prodigies',
#   'description': 'Follow five extraordinarily talented Australian children and their families as we take an intimate and candid look at their lives at a pivotal time in their careers and ask, what does it take to be a child prodigy?',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1703H_5b0b3ff352618_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/making-child-prodigies'},
#  {'title': 'Cracking COVID',
#   'description': "Tracking the real-time story of Australia's scientific response to the pandemic. As teams of scientists unlock the secrets of the virus, researchers work to build a vaccine, and patients confront symptoms of this new disease.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2005V001S00_60d9334a88f4f_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/cracking-covid/video/DO2005V001S00'},
#  {'title': 'The China Century',
#   'description': "The forces that have powered China's rise are rarely explored, while the lives of Chinese people barely get a mention. Beyond the headlines what do we really know about China and its 1.4 billion citizens?",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1950H_61cd1e0378aaa_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/china-century'},
#  {'title': 'New Dads',
#   'description': 'Jane Caro meets five Australian men navigating their first year as new dads to see how they are managing the life changing transition into fatherhood.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1811H026S00_5d65d0d4bc496_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/new-dads/video/RN1811H026S00'},
#  {'title': 'Aussie Inventions That Changed the World',
#   'description': 'From life-saving devices to modern conveniences, this eight-part series reveals a raft of great Australian inventors who turned game-changing ideas into a reality and forever changed how we live.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2425A_6023608bc132a_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/aussie-inventions-that-changed-the-world'},
#  {'title': 'Ready Together',
#   'description': "Craig Reucassel presents the stories of two communities devastated by Australia's black Summer bushfires, exploring how these communities are strengthening their capacity to respond and prepare for the future.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2022H001S00_605d0e361b377.jpg',
#   'url': 'https://iview.abc.net.au/show/ready-together/video/DO2022H001S00'},
#  {'title': 'Who Killed Belinda Peisley? Uncovered',
#   'description': "This 6-part series of digital extras takes the viewer deeper into the events of Belinda Peisley's murder case, including a closer look at the people and events surrounding Belinda at the time of her disappearance.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/dc/DC1709H_5b6a523c6385d_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/who-killed-belinda-peisley-uncovered'},
#  {'title': 'The School That Tried To End Racism (UK)',
#   'description': 'A ground-breaking series following a pioneering British school as it tries to help its students uncover and eradicate hidden racial biases.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3180A_61e63b0a75802.jpg',
#   'url': 'https://iview.abc.net.au/show/school-that-tried-to-end-racism-uk'},
#  {'title': "Lucy Worsley's Royal Palace Secrets",
#   'description': 'Historian Lucy Worsley takes us behind closed doors at three treasure-filled royal palaces - the Tower of London, Hampton Court and Kensington Palace - to uncover how each building has shaped a monarchy and a nation.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2639A001S00_606bef561198c.jpg',
#   'url': 'https://iview.abc.net.au/show/lucy-worsley-s-royal-palace-secrets/video/ZW2639A001S00'},
#  {'title': '9/11: Life Under Attack',
#   'description': '9/11 was the first major news event in the age of digital cameras and voicemails. This remarkable film tells the never-before-told stories of that day, created through a tapestry of previously unseen video and unheard audio.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3079A001S00_6124670cde10d.jpg',
#   'url': 'https://iview.abc.net.au/show/9-11-life-under-attack/video/ZW3079A001S00'},
#  {'title': 'Cyber Dreaming',
#   'description': 'Graphic artist Stuart Campbell has developed his unique artistic practice in relative isolation but decides to share his work with a group of Indigenous kids in outback Australia.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/publicity_AC1342H001S00.jpg',
#   'url': 'https://iview.abc.net.au/show/cyber-dreaming/video/AC1342H001S00'},
#  {'title': 'Our Dawn',
#   'description': 'Our champion and our inspiration, swimming legend Dawn Fraser opens up to Tracey Holmes about her life, swimming career, winning Gold, the 1964 Tokyo Games and the theft of that Flag that cost Dawn her Olympic future.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ns/NS2144H001S00_60ecd180c66c0_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/our-dawn/video/NS2144H001S00'},
#  {'title': 'Luke Warm Sex',
#   'description': 'This series is a crash course in great sex. Luke McGregor takes on a new challenge with the help of therapists, sex coaches & scientists, proving if someone as anxious as Luke can get better at sex, then anyone can!',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/le/publicity_LE1418V.jpg',
#   'url': 'https://iview.abc.net.au/show/luke-warm-sex'},
#  {'title': 'Back To Nature',
#   'description': 'A journey through the Australian landscape and the unique stories of the land, deepening our connection with nature.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1909H_613eb2b2f25a1_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/back-to-nature'},
#  {'title': 'Secrets of the Museum',
#   'description': 'Inside every museum is a hidden world. Now in a brand new season all will be revealed, as we witness the weird and the wonderful behind the exhibits.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3090A_6143def582f87.jpg',
#   'url': 'https://iview.abc.net.au/show/secrets-of-the-museum'},
#  {'title': 'The Penguin King With David Attenborough',
#   'description': "The Penguin King's story is often comical, sometimes tragic, and ultimately triumphant: a rite of passage set on one of the earth's last great wildernesses.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2595A001S00_5fd9a41c3d21a_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/penguin-king-with-david-attenborough/video/ZW2595A001S00'},
#  {'title': 'The Pool',
#   'description': 'Pools are a defining part of our national identity. Evoking deep nostalgia and childhood memories, this two-part documentary takes a look at the Australian identity through the prism of the pool.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rf/RF1806H_5d6dc9d82af26.jpg',
#   'url': 'https://iview.abc.net.au/show/pool'},
#  {'title': 'Ballet Now',
#   'description': 'This film captures the creative process behind the scenes at the famed Dorothy Chandler Pavilion - bringing dancers, choreographers and styles from all over the world together for three magical nights of performances.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2691A001S00_60caa8b2cbb79_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/ballet-now/video/ZW2691A001S00'},
#  {'title': "David Attenborough's Tasmania",
#   'description': "David Attenborough narrates the story of a vast island wilderness: ancient forests, pristine rivers and spectacular coastline. From dry heat to strong cold winds, it's home to wombats, wallabies and platypus.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1100A001S00_5b0ce2ca5a6c3.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-tasmania/video/ZW1100A001S00'},
#  {'title': "Bangarra's World",
#   'description': "Join the dancers and creatives during Bangarra Dance Theatre's 30th anniversary as they travel Australia; stage major dance works and show us what it's like to inhibit some of the most iconic roles in Australian dance.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ar/AR1942H_60e24872c4eb5_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/bangarra-s-world'},
#  {'title': "Anh's Brush With Fame",
#   'description': "Anh Do paints some of Australia's most famous faces and captures their personalities on the canvas. The charismatic comedian, writer and Archibald Finalist delves into the inspirational stories that have shaped their lives.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2030H_60503c0821523.jpg',
#   'url': 'https://iview.abc.net.au/show/anh-s-brush-with-fame'},
#  {'title': "David Attenborough's First Life",
#   'description': 'David Attenborough traces the origin of life, going back to the very roots of the tree of life, in search of the very first animals that moved, to the first predators that killed and the first legs that walked on land.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX0951A_61286d5f2f4f3_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-first-life'},
#  {'title': 'Dubboo: Life Of A Songman',
#   'description': "Bangarra Dance Theatre joins forces with some of our most celebrated and iconic Indigenous artists in this beautiful commemorative show at Carriageworks, honouring composer and actor David Page - Bangarra's long-time songman.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1942H001S00_60deb1b5e65c1_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/dubboo-life-of-a-songman/video/AC1942H001S00'},
#  {'title': 'Can We Save The Reef?',
#   'description': 'An epic story of Australian and international scientists who are racing to understand our greatest natural wonder and employing cutting edge science in an attempt to save it.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/sc/SC1606H001S00_5af52d51e535c_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/can-we-save-the-reef/video/SC1606H001S00'},
#  {'title': 'Wild Australia: After the Fires',
#   'description': "Charting the recovery of wildlife in the aftermath of Australia's catastrophic bushfires through stories of hope and resilience. Narrated by Hugo Weaving, the film provides an urgent message to safeguard our environment.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1918H001S00_5fb354d83f7b0.jpg',
#   'url': 'https://iview.abc.net.au/show/wild-australia-after-the-fires/video/DO1918H001S00'},
#  {'title': 'The Bikes Of Wrath',
#   'description': 'Five Australian friends cycle from Oklahoma to California in honour of the Dust Bowl migration. The group explores whether America has progressed since the book was written, discussing the wealth gap and the American Dream.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1806V001S00_5d083a2724d19.jpg',
#   'url': 'https://iview.abc.net.au/show/bikes-of-wrath/video/AC1806V001S00'},
#  {'title': 'Employable Me Australia',
#   'description': "The Rose d'Or nominated series follows six individuals with disabilities on their journey to find a job; highlighting their skills and talents, as they work with experts and job coaches to harness their strengths.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1829H_5c998df729622.jpg',
#   'url': 'https://iview.abc.net.au/show/employable-me-australia'},
#  {'title': 'The Twist',
#   'description': "The award-winning animated series that brings to life some of Australia's most intriguing crime stories. These were crimes of passion, old-fashioned gangland homicides and mysteries that captivated the entire nation.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1713H_5d65d42a815c2_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/twist'},
#  {'title': 'Stackorama!',
#   'description': 'Jaydyn Coggins, the best cup stacker in Australia, travels to the World Sports Stacking Championships in Florida. Dogged by a series of setbacks, Jaydyn must call on all his skill and family support for a shot at his dreams.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1917S001S00_60503de70551a.jpg',
#   'url': 'https://iview.abc.net.au/show/stackorama/video/DO1917S001S00'},
#  {'title': 'To The Stars: 100 Years Of The RAAF',
#   'description': 'As the Royal Australian Air Force marks its 100th anniversary we look at the illustrious history of the RAAF, through rare archival footage and in-depth interviews with air force veterans, servicing members and new recruits.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ns/NS2135H001S00_606144fe060e7_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/to-the-stars-100-years-of-the-raaf/video/NS2135H001S00'},
#  {'title': 'Final Rendezvous',
#   'description': 'The collapse of a major spy case involving a female double agent haunted ASIO throughout the Cold War. A new investigation of surveillance film reveals what went wrong and uncovers a possible KGB murder on Australian soil.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2361A001S00_5f21141f2e86f_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/final-rendezvous/video/ZW2361A001S00'},
#  {'title': 'Heywire',
#   'description': 'Heywire is young regional Australians telling it like it is. They share candid and courageous stories about life outside the big cities.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ra/RA2003H_5f34e153383dd_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/heywire'},
#  {'title': 'Step Into Paradise',
#   'description': 'The extraordinary story of iconic fashion designers Jenny Kee and Linda Jackson, whose pioneering style created a bold and unashamedly Australian fashion identity. (2020)',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1906H001S00_6152912635c40.jpg',
#   'url': 'https://iview.abc.net.au/show/step-into-paradise/video/AC1906H001S00'},
#  {'title': 'Countdown To War',
#   'description': 'On Friday 1st September 1939, Germany invaded Poland and the clock started ticking. On Sunday morning, Britain had declared war. Learn about the three days that led up to the Second World War and changed the world forever.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3208A_61fb702400286_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/countdown-to-war'},
#  {'title': 'Uncle Vic',
#   'description': "Nothing gets between Vic Ludwig and his football - especially his age. The 92-year-old's dedication to his beloved St Mary's Football Club has earned him the title of the longest-ever serving club president in AFL.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2027D001S00_60e2a4314791d_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/uncle-vic/video/DO2027D001S00'},
#  {'title': 'The Planets',
#   'description': 'This stunningly ambitious series brings to life the most memorable events in the history of the solar system, by using ground breaking visual effects to tell the thrilling story of all eight planets.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1995A_5d43b6c46e8be_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/planets'},
#  {'title': 'Invisible Wars',
#   'description': "A rapidly moving, highly lethal airborne pathogen sweeps the planet killing 80 million people, wiping out 5% of the world's economy and plunging society into chaos. Experts explore the rise and fall of infectious diseases.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1956H_607fbdb04c6f5_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/invisible-wars'},
#  {'title': 'Ask The Doctor',
#   'description': "Ask the Doctor is an innovative, fun, and exploratory factual series that addresses the state of the nation's health, the latest in medical treatments and the future of healthcare as we know it.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1708V_5ba98ee875b14.jpg',
#   'url': 'https://iview.abc.net.au/show/ask-the-doctor'},
#  {'title': "Rulla's Connection to Country",
#   'description': 'Indigenous Tasmanian man Rulla Kelly-Mansell tells the story of how his cultural connection to country helped him to overcome mental health challenges, a battle with cancer and isolation during the pandemic.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rf/RF2102S001S00_61650fb99f2a1_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/rulla-s-connection-to-country/video/RF2102S001S00'},
#  {'title': 'Tickled',
#   'description': "Journalist David Farrier stumbles upon a mysterious tickling competition online. As he delves deeper he comes up against fierce resistance, but that doesn't stop him getting to the bottom of a story stranger than fiction. (2016)",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW0933A001S00_5b160c656b34a_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/tickled/video/ZW0933A001S00'},
#  {'title': 'What Was It Like?',
#   'description': 'Eight filmmakers with intellectual disability interview their parents about what it was like when doctors delivered the news of their diagnosis.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rf/RF2101H003S00_61bfd376c4c94.jpg',
#   'url': 'https://iview.abc.net.au/show/what-was-it-like/video/RF2101H003S00'},
#  {'title': "David Attenborough's Flying Monsters",
#   'description': 'For thousands of years, humans have believed that there were once flying monsters. But did they really exist beyond our wildest imaginations? Sir David Attenborough sets out to uncover the truth.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX9703A001S00_605adf463e759_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-flying-monsters/video/ZX9703A001S00'},
#  {'title': 'The School That Tried To End Racism',
#   'description': 'Marc Fennell explores a ground-breaking school program designed to provide a class of primary school students with the tools to identify racial bias and make positive change.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2021H_611b25f569f0c.jpg',
#   'url': 'https://iview.abc.net.au/show/school-that-tried-to-end-racism'},
#  {'title': "David Attenborough's Life That Glows",
#   'description': "Join Sir David Attenborough and a team of the world's leading scientists and deep sea explorers on a quest to reveal the secrets of living lights.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW0730A001S00577460dd079d24.96528294_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-life-that-glows/video/ZW0730A001S00'},
#  {'title': 'Dementia & Us',
#   'description': "This two-part series follows four people with dementia over the course of two years. A telling insight into what it's really like to live with the condition, following the ups and downs of life with a changing brain.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3250A_61f8aa6b91b32.jpg',
#   'url': 'https://iview.abc.net.au/show/dementia-and-us'},
#  {'title': 'Nolan',
#   'description': "Sidney Nolan is one of Australia's greatest artists. His iconic images are treasures of the Australian visual language. This film explores the artist and the man from his early years to his extraordinary international career.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1729V001S00_5bd7c7181acb2.jpg',
#   'url': 'https://iview.abc.net.au/show/nolan/video/AC1729V001S00'},
#  {'title': 'Catching A Killer: A Knock At The Door',
#   'description': 'The life of 64-year-old Hang Yin Leung and her hard-working family are changed forever one fateful night in January, 2017.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2742A001S00_6090e57648bba.jpg',
#   'url': 'https://iview.abc.net.au/show/catching-a-killer-a-knock-at-the-door/video/ZW2742A001S00'},
#  {'title': "Julia Zemiro's Home Delivery",
#   'description': 'Julia Zemiro invites notable personalities to join her on a nostalgia filled trip to discover the people, places, and stories that have made them who they are today.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/le/LE1961H_5eb0dd08f0cd7.jpg',
#   'url': 'https://iview.abc.net.au/show/julia-zemiro-s-home-delivery'},
#  {'title': 'Rosemary Valadon: A Sensual World',
#   'description': 'Rosemary Valadon: A Sensual World looks at the art and influences of a multi award-winning Australian painter whose work has reinterpreted a distinctly Australian femininity and domestic aesthetic.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1606H001S00_58e18b1f45a93_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/rosemary-valadon-a-sensual-world/video/AC1606H001S00'},
#  {'title': "Kevin McCloud's Grand Tour",
#   'description': "Clambering amongst the greatest buildings, ruins and cities in Europe, Kevin McCloud uncovers the dark underbelly of the 'Grand Tour' in the shady alleys and drinking dens along its route, exploring the Tour's lasting legacy.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX0800A_60c01256e4bc6.jpg',
#   'url': 'https://iview.abc.net.au/show/kevin-mccloud-s-grand-tour'},
#  {'title': 'The Upside',
#   'description': "Julia Hales explores people's thoughts when they face a decision about having a baby with Down Syndrome and re-examines her experience as she confronts parents' fears and celebrates the joys of living with Down Syndrome.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1911H028S00_5f8794f8120fe_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/upside/video/RN1911H028S00'},
#  {'title': 'Weird Australia',
#   'description': "With the help of eyewitness accounts, qualified experts and amateur footage, Moataz Hamde explores the uncanny truth behind some of Australia's bizarre natural phenomena. From tornadoes made of fire, to neon pink lakes and waterfalls that run sideways, Mo delves into the strangest, most mind-boggling things that Aussie nature can serve up.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/sq/SQ2103H001S00_61b9147f5be00_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/weird-australia/video/SQ2103H001S00'},
#  {'title': 'a-ha The Movie',
#   'description': "a-ha's hit Take On Me is still one of the most played songs of the last millennium. This film follows the band over four years, sharing the full story of how three young men followed their impossible dream of making it big. (2021)",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3088A001S00_612f1de387f2e_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/a-ha-the-movie/video/ZW3088A001S00'},
#  {'title': 'The Wonder Of Marsupials',
#   'description': "From Australia's scorching desert heart to pristine rainforests in the north, we'll meet the biggest and the smallest marsupials, the rarest and the most successful as we journey to see the Wonder of Marsupials.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ai/AI1855H_60b6c9cd9212c_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/wonder-of-marsupials'},
#  {'title': "Devil's Advocate",
#   'description': 'Follow the story of Simon Plowright, a cinematographer and nature lover who has become one of the Tasmanian Devils greatest advocates.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1101A001S00_5b162148e8587_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/devil-s-advocate/video/ZW1101A001S00'},
#  {'title': 'Maralinga Tjarutja',
#   'description': 'The Maralinga people survive aggressive colonisation, including dispossession to enable atomic testing, and through their tenacious spirit and cultural strength fight to retain their country.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ip/IP1903S001S00_5eba31c86de8b.jpg',
#   'url': 'https://iview.abc.net.au/show/maralinga-tjarutja/video/IP1903S001S00'},
#  {'title': "David Attenborough's Conquest Of The Skies",
#   'description': 'David Attenborough embarks on an extraordinary journey to search for the origins of animal flight, beginning his epic global exploration in the unexpectedly skillful world of the flying insects.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX9702A_6059670eb48d5_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/david-attenborough-s-conquest-of-the-skies'},
#  {'title': "Griff's Great Kiwi Road Trip",
#   'description': 'British comedian and travel enthusiast Griff Rhys Jones is packing his bags, pulling on his hiking boots, and heading out into the wilds to explore New Zealand - from the the North Island to the South Island.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1850A_5de5e238538ec.jpg',
#   'url': 'https://iview.abc.net.au/show/griff-s-great-kiwi-road-trip'},
#  {'title': "You Can't Ask That: Invictus Games",
#   'description': "The ABC's award-winning You Can't Ask That asks the tough questions to former and current members of the Australian Invictus Games team.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/lr/LR1717H_5bbc2a59edf6c.jpg',
#   'url': 'https://iview.abc.net.au/show/you-can-t-ask-that-invictus-games'},
#  {'title': 'Prisoners and Pups',
#   'description': 'A small group of women prisoners have just eight weeks to transform retired racing greyhounds into obedient, house-friendly pets. Can the dogs help the women get their lives back on track?',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO1521S_59eed797556c7.jpg',
#   'url': 'https://iview.abc.net.au/show/prisoners-and-pups'},
#  {'title': "Kumi's Japan",
#   'description': 'Kumi travels to Japan to deliver news to a family she hopes still exists, about a father she never really knew. Her identity is challenged as she tries to understand why she feels so at home in this intoxicating country.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1811H027S00_5d92dfe55d240.jpg',
#   'url': 'https://iview.abc.net.au/show/kumi-s-japan/video/RN1811H027S00'},
#  {'title': 'Secrets of Althorp with Charles Spencer',
#   'description': 'Charles Spencer, Earl, historian and brother of Princess Diana invites an archaeological dig to Althorp, his historical home, in search of a lost Anglo Saxon village.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3085A001S00_61a59be90e7ce.jpg',
#   'url': 'https://iview.abc.net.au/show/secrets-of-althorp-with-charles-spencer/video/ZW3085A001S00'},
#  {'title': 'Lockdown Stories',
#   'description': 'Seven participants were chosen to document their lives for Lockdown Stories. The result is a range of very different stories, intimate, moving, funny and heart-warming as they share their personal experience in lockdown.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rn/RN1911H027S00_5f6abb3cafd7f_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/lockdown-stories/video/RN1911H027S00'},
#  {'title': 'The Art Of Australia',
#   'description': "The Art of Australia explores how art and artists helped to shape Australia's national identity.",
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1230H_608756d13ba1b_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/art-of-australia'},
#  {'title': 'And We Danced',
#   'description': 'The Australian Ballet has evolved to become our nations most treasured performing arts company and an icon of dance. And We Danced looks back to reveal what has shaped this world-class institution and made it uniquely ours.',
#   'category_name': 'documentary',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1945H_60da86d6e92a6.jpg',
#   'url': 'https://iview.abc.net.au/show/and-we-danced'},
#  {'title': "The Making Of David Attenborough's Galapagos",
#   'description': "The making of the groundbreaking three-part series - David Attenborough's Galapagos.",
# ...
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zx/ZX9582A001S00558d33b58504e9.01512620_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/pina/video/ZX9582A001S00'},
#  {'title': 'Songs Of Praise: Blenheim Palace',
#   'description': 'Aled Jones visits Blenheim Palace to explore its private chapel and magnificent grounds, and Laura Wright joins an inclusive choir for a hymn singalong.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3181A001S00_61e63b0ae5528.jpg',
#   'url': 'https://iview.abc.net.au/show/songs-of-praise-blenheim-palace/video/ZW3181A001S00'},
#  {'title': 'Ties That Bind',
#   'description': '17 year-old Thomas has to front his domineering mother Marlene. Forced outside as punishment, sounds from neighbours echo a connection to his past and present home triggering Thomas to make a life changing decision.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ip/IP1801V001S00_5f98eb7d6b303_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/ties-that-bind/video/IP1801V001S00'},
#  {'title': 'Whiteley',
#   'description': "A visual journey into the private life and creative legacy of Australia's most iconic artist, Brett Whiteley, told using personal letters, photographs, interwoven with reconstructions, archival interviews and rare footage. (2017)",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW1383A001S00_5b161b68ace61.jpg',
#   'url': 'https://iview.abc.net.au/show/whiteley/video/ZW1383A001S00'},
#  {'title': 'A Life In Ten Pictures',
#   'description': "A famous figure's life, distilled into ten key turning points, captured in ten iconic photographs. What do these images reveal about their subjects? What secrets do they hide? Does the camera reveal the pain behind a smile?",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2819A_609c63721d193_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/life-in-ten-pictures'},
#  {'title': 'Beethoven Celebration Berlin',
#   'description': "In 2020, Ludwig van Beethoven is the focus of the Staatskapelle Berlin's suberb open-air concert featuring star violinist Anne-Sophie Mutter playing Beethoven's Violin Romances Nos. 1 and 2.",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3091A001S00_6124670d2dc44.jpg',
#   'url': 'https://iview.abc.net.au/show/beethoven-celebration-berlin/video/ZW3091A001S00'},
#  {'title': 'What Is Music?',
#   'description': "Why do we love a good beat? Does classical music really make you smarter? Join triple j's Linda Marigliano and composer Dan Golding as they explore the electrifying fusion of emotion and science in music.",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/le/LE1719H_5b581bf12e092_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/what-is-music'},
#  {'title': 'Devolution: A Devo Theory',
#   'description': "Enter the minds of one of history's most misunderstood bands. With hits such as 'Whip It' & 'Freedom of Choice', they shared a trailblazing environmental message but were often mocked. 40 years later, we ask: were Devo right?",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2602A001S00_602c553e284cc_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/devolution-a-devo-theory/video/ZW2602A001S00'},
#  {'title': 'The Merry Widow',
#   'description': 'The Merry Widow is a lively tale of love, money and class, plays out against the glitter and opulence of the belle epoque. Commissioned and performed by The Australian Ballet. Music performed by Opera Australia Orchestra.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2295A001S00_60765708c363e_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/merry-widow/video/ZW2295A001S00'},
#  {'title': 'Oils On The Water',
#   'description': 'In 1985, Midnight Oil celebrated in concert on Goat Island, on Sydney Harbour in an event that will be remembered as one of the triumphs of their careers.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2970A001S00_60beb09c351aa_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/oils-on-the-water/video/ZW2970A001S00'},
#  {'title': 'Sleeping Beauty',
#   'description': "The Australian Ballet presents Sleeping Beauty, in a production by David McAllister. With lavish sets and costumes, this ballet casts a spell of delight all the way to true love's kiss. Music performed by Orchestra Victoria.",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2298A001S00_5eb0ff01c4ea5_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/sleeping-beauty/video/ZW2298A001S00'},
#  {'title': "triple j's One Night Stand, Lucindale",
#   'description': 'triple j takes the live music experience to a town not usually on the touring map - Lucindale in South Australia. With performances by Hilltop Hoods, Meg Mac, Ocean Alley and G Flip.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/rk/RK1902S_5d771f056a0c5_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/triple-j-s-one-night-stand-lucindale'},
#  {'title': 'Desert Metal Dreaming',
#   'description': 'The most isolated metal band in the world, Southeast Desert Metal, and their Aunty Kathleen, share ancient Arrernte culture with the world through song and painting.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/do/DO2025D001S00_60dd2967cea0b_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/desert-metal-dreaming/video/DO2025D001S00'},
#  {'title': 'One Plus One',
#   'description': 'Some of your favourite ABC presenters bring you more revealing, thought provoking and intimate half hour conversations with fascinating people from all walks of life.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/nc/NC1913H_5d830acf1b4b2_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/one-plus-one'},
#  {'title': 'Bird Nerd: The Art Of Leila Jeffreys',
#   'description': "This intimate portrait follows beloved Australian bird photographer Leila Jeffreys' childhood in the Australian bush, through the grief of losing her father to her first exhibition in New York.",
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1801H001S00_5d8c102559761.jpg',
#   'url': 'https://iview.abc.net.au/show/bird-nerd-the-art-of-leila-jeffreys/video/AC1801H001S00'},
#  {'title': "Barrie Cassidy's One Plus One",
#   'description': 'Barrie Cassidy returns for a new season of One Plus One, with a series of in-depth conversations exploring how Australians have coped during COVID-19 pandemic.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/nc/NC2131H_6195c5d02e20a_3600.jpg',
#   'url': 'https://iview.abc.net.au/show/barrie-cassidy-s-one-plus-one'},
#  {'title': 'Crowded House Live At Sydney Opera House',
#   'description': 'An unforgettable event from the steps of Sydney Opera House. In 2016 Crowded House returned to play a cavalcade of their hits and favourites 20 years after their landmark last concert.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/fa/FA1601H001S00_607632d6892e7_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/crowded-house-live-at-sydney-opera-house/video/FA1601H001S00'},
#  {'title': 'triple j Like A Version',
#   'description': 'A popular segment recorded at triple j studios which gives local and international acts a chance to pay homage to their favourite artists by performing a cover of one of their songs.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/iv/IV2201H_61cd0ea5e9eda.jpg',
#   'url': 'https://iview.abc.net.au/show/triple-j-like-a-version'},
#  {'title': 'The Art of Collecting',
#   'description': 'These short intimate stories by artist Kate Blackmore uncover the meaning, memories, and inspiration behind the often weird and wonderful personal collections of five Australian artists.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ac/AC1940H006S00_60c975adba302_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/art-of-collecting/video/AC1940H006S00'},
#  {'title': 'Shed',
#   'description': 'An enslaved girl, Mary, endures daily torture in a world with no prospects until a new station hand, Victor, walks into the shed and her life.',
#   'category_name': 'arts-and-culture',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/ip/IP1803Q001S00_5f98ea5ca4917_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/shed/video/IP1803Q001S00'},
#  {'title': 'Starman',
#   'description': "An alien stranded on Earth clones himself into the form of a young woman's deceased husband, kidnapping her as he attempts to reunite with his spacecraft to make his way home. (1984)",
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3016A001S00_60c15c7beb10f_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/starman/video/ZW3016A001S00'},
#  {'title': 'Mr Deeds Goes To Town',
#   'description': 'A small-town poet inherits a vast fortune and finds himself in New York City where he is faced with the corruption of city life and people whose motivations are not what they seem. (1936)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3025A001S00_60c14e5bceebb_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/mr-deeds-goes-to-town/video/ZW3025A001S00'},
#  {'title': 'The Boys Are Back',
#   'description': "Journalist Joe Warr and his two sons, from different marriages, find themselves living in a boys-only household following the death of Joe's second wife. A humorous journey from part-time dad to full-on fatherhood. (2009)",
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2380A001S00_5ee1d17b30837_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/boys-are-back/video/ZW2380A001S00'},
#  {'title': 'On A Clear Day',
#   'description': 'Frank determines to salvage his self-esteem and tackle his demons by attempting the ultimate test of endurance, swimming the English Channel. (2004)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2910A001S00_609c85a181602_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/on-a-clear-day/video/ZW2910A001S00'},
#  {'title': 'The Way We Were',
#   'description': 'A love story that begins with the attraction of opposites, Katie and Hubbell fall in love with each other but soon realise that the things important to them in life are pulling them apart. (1973)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zy/ZY9332A001S00_60c158d038bb3_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/way-we-were/video/ZY9332A001S00'},
#  {'title': 'Another Year',
#   'description': 'Follow happily-married couple Tom and Gerri and their friends and family over four seasons, as they negotiate life with kindness, love and good cheer. (2010)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2848A001S00_609c6c3177ffa_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/another-year/video/ZW2848A001S00'},
#  {'title': "Secret Men's Business",
#   'description': "Four former private school boys' reunite to attend the funeral of their beloved but mysterious school master. The weekend of sun, surf, women and late-night reminiscing leads to hard truths that had long been left behind. (1999)",
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/dr/DR9812H001S00_60c93ef594e32_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/secret-men-s-business/video/DR9812H001S00'},
#  {'title': 'The Lost Aviator',
#   'description': 'Set in the Golden Age of Aviation, Andrew Lancaster follows the life and times of his great uncle, Captain Bill Lancaster, and uncovers a fascinating tale of adventure, obsession, love and a sensational murder trial. (2014)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2779A001S00_609214194a2df_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/lost-aviator/video/ZW2779A001S00'},
#  {'title': 'On The Road',
#   'description': 'Aspiring writer Sal Paradise has his world rocked following the introduction of free spirit Dean Moriarty and his captivating bride Marylou. The trio embark on a cross-country quest for personal freedom. (2012)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2911A001S00_609b9aa2da3be_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/on-the-road/video/ZW2911A001S00'},
#  {'title': 'Stand By Me',
#   'description': 'After learning that a stranger has been accidentally killed near their rural homes, four young boys decide to go see the body. What seems like a lark at first soon turns out to be a defining moment in their lives. (1986)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3006A001S00_60c19ee692c31.jpg',
#   'url': 'https://iview.abc.net.au/show/stand-by-me/video/ZW3006A001S00'},
#  {'title': 'Trust The Man',
#   'description': 'Two New York couples; a successful actress, her househusband, her ne-er-do-well brother and his girlfriend, juggle work demands and infidelity as they search for real love, and easy parking. (2005)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2860A001S00_60b44217e0f16_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/trust-the-man/video/ZW2860A001S00'},
#  {'title': 'Splinter',
#   'description': 'A young couple and an escaped convict are trapped in an isolated gas station by a voracious splinter parasite that transforms its still-living victims into deadly hosts. Will they survive this primal terror? (2008)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2874A001S00_60a74c2e1d5e1_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/splinter/video/ZW2874A001S00'},
#  {'title': 'A Raisin In The Sun',
#   'description': 'When a recently widowed matriarch receives a large sum of money from insurance, she soon learns that everyone in her family has their own ideas about how the money should be spent. (1961)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3017A001S00_60c16fed32da4_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/raisin-in-the-sun/video/ZW3017A001S00'},
#  {'title': 'Funny Girl',
#   'description': 'The life of the 1930s comedienne Fannie Brice, from her early days in the Jewish slums of New York, to the height of her career with the Ziegfeld Follies. (1968)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW3026A001S00_60c1559582fdd_2048.jpg',
#   'url': 'https://iview.abc.net.au/show/funny-girl/video/ZW3026A001S00'},
#  {'title': 'Little Fish',
#   'description': 'After a turbulent time in her 20s, Tracy Heart is now trying to live the straight life, having freed herself from the grip of heroin addiction. (2005)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zy/ZY9705A001S00_5ff7f1c9070a0_1920.jpg',
#   'url': 'https://iview.abc.net.au/show/little-fish/video/ZY9705A001S00'},
#  {'title': 'The Sorcerer and the White Snake',
#   'description': 'A master monk tries to protect a naive young physician from a thousand-year-old snake demon. A contest of psychic powers results in mayhem. Starring international action legend, Jet Li. (2011)',
#   'category_name': 'movies',
#   'thumbnail': 'https://cdn.iview.abc.net.au/thumbs/i/zw/ZW2873A001S00_60b43e5d16b89_1280.jpg',
#   'url': 'https://iview.abc.net.au/show/sorcerer-and-the-white-snake/video/ZW2873A001S00'},
#  ...]

# %%
# Uncomment if running for the first time

### Convert dictionary to DataFrama and save csv


df = pd.DataFrame(raw_data)
df.tail()

#save to csv
df.to_csv("../data/ABC_parsed.csv", index=False, sep=';')

# %%
# Read the .csv file from above

df = pd.read_csv("../data/ABC_parsed.csv", sep=';')
df.tail(10)
# Out:
#                          title  \
# 1528          Accidents Happen
# 1529             Ackley Bridge
# 1530            Train To Busan
# 1531              The Warriors
# 1532               Human Touch
# 1533                    Veneno
# 1534            Starter For 10
# 1535  The Larkins At Christmas
# 1536              13 Assassins
# 1537                    Bucket
#
#                                             description category_name  \
# 1528  A wickedly funny and surprisingly moving fable...         drama
# 1529  In a Yorkshire town, the merging of two school...         drama
# 1530  As a zombie outbreak sweeps South Korea, a fat...         drama
# 1531  A struggling football team, the Warriors, plac...         drama
# 1532  A woman raising money for her choir finds hers...         drama
# 1533  Valeria is in for the adventure of a lifetime ...         drama
# 1534  The spirited coming-of-age tale of Brian Jacks...         drama
# 1535  The Larkins are preparing for Christmas, but t...         drama
# 1536  When the sadistic excesses of Lord Matsudaira ...         drama
# 1537  When eccentric, free-spirited Mim tells her hi...         drama
#
#                                               thumbnail  \
# 1528  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW297...
# 1529  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW274...
# 1530  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW286...
# 1531  https://cdn.iview.abc.net.au/thumbs/i/ip/IP150...
# 1532  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW289...
# 1533  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW307...
# 1534  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW286...
# 1535  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW313...
# 1536  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW284...
# 1537  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW122...
#
#                                                     url
# 1528  https://iview.abc.net.au/show/accidents-happen...
# 1529        https://iview.abc.net.au/show/ackley-bridge
# 1530  https://iview.abc.net.au/show/train-to-busan/v...
# 1531             https://iview.abc.net.au/show/warriors
# 1532  https://iview.abc.net.au/show/human-touch/vide...
# 1533               https://iview.abc.net.au/show/veneno
# 1534  https://iview.abc.net.au/show/starter-for-10/v...
# 1535  https://iview.abc.net.au/show/larkins-at-chris...
# 1536  https://iview.abc.net.au/show/13-assassins/vid...
# 1537               https://iview.abc.net.au/show/bucket

# %%
# Check counts of each category
df.category_name.value_counts()
# Out:
# drama                   240
# documentary             210
# education               181
# kids                    171
# family                  155
# movies                  143
# comedy                  130
# arts-and-culture        115
# news-current-affairs    102
# lifestyle                53
# panel-and-discussion     38
# Name: category_name, dtype: int64

# %%
# Preprocessing through lemmatizing using NLTK.
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
# Adding a column that contains both category and description
# This column
df['category_title_description'] = df['category_name'] + ' ' + df['title'] + ' ' + df['description']
df.tail(5)

# print(df.columns)  #to check if the columns are right
# Out:
#                          title  \
# 1533                    Veneno
# 1534            Starter For 10
# 1535  The Larkins At Christmas
# 1536              13 Assassins
# 1537                    Bucket
#
#                                             description category_name  \
# 1533  Valeria is in for the adventure of a lifetime ...         drama
# 1534  The spirited coming-of-age tale of Brian Jacks...         drama
# 1535  The Larkins are preparing for Christmas, but t...         drama
# 1536  When the sadistic excesses of Lord Matsudaira ...         drama
# 1537  When eccentric, free-spirited Mim tells her hi...         drama
#
#                                               thumbnail  \
# 1533  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW307...
# 1534  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW286...
# 1535  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW313...
# 1536  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW284...
# 1537  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW122...
#
#                                                     url  \
# 1533               https://iview.abc.net.au/show/veneno
# 1534  https://iview.abc.net.au/show/starter-for-10/v...
# 1535  https://iview.abc.net.au/show/larkins-at-chris...
# 1536  https://iview.abc.net.au/show/13-assassins/vid...
# 1537               https://iview.abc.net.au/show/bucket
#
#                              category_title_description
# 1533  drama Veneno Valeria is in for the adventure o...
# 1534  drama Starter For 10 The spirited coming-of-ag...
# 1535  drama The Larkins At Christmas The Larkins are...
# 1536  drama 13 Assassins When the sadistic excesses ...
# 1537  drama Bucket When eccentric, free-spirited Mim...

# %%
def clean_text(x, stop_words):
  if pd.isna(x) == False:
    x = x.lower()
    x = x.translate(str.maketrans(' ', ' ', string.punctuation))
    x = x.strip()

    x = nltk.word_tokenize(x)
    x = [token for token in x if not token in stop_words]
    x = ' '.join([lemmatizer.lemmatize(w) for w in x])
  else:
    x = ''

  return x

# %%
# stop_words = stopwords.words('english')
stop_words = nltk.corpus.stopwords.words('english')
# print(stop_words[:10])

df['Text'] = df['category_title_description'].apply(lambda x: clean_text(x, stop_words))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn import cluster

vectorizer = TfidfVectorizer(min_df=2, max_df=0.9, norm='l2')
X = vectorizer.fit_transform(df['Text'])
tf_idf = pd.DataFrame(data = X.toarray(), columns=vectorizer.get_feature_names())

# tf_idf   # Uncomment to display the tf_idf matrix
# Out:
# /Users/handrajati/miniforge3/envs/INFOMPPM-docker/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
## Use silhouette score to find if there is a significantly optimal number of clusters

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

range_n_clusters = list (range(2,40))

for n_clusters in range_n_clusters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(tf_idf)
    centers = clusterer.cluster_centers_

    score = silhouette_score(tf_idf, preds)

    ## Uncomment to see silhouette score for n = [2,40]
    # print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))

# %%
clusters = 10
kmeanModel = KMeans(n_clusters=clusters,
                    init='k-means++',
                    max_iter=3000,
                    random_state=0)
mod = kmeanModel.fit_transform(tf_idf)
df['k_means'] = kmeanModel.predict(tf_idf)

# %%
order_centroids = kmeanModel.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
dict = []

# Print top terms in each cluster
for i in range(clusters):
  print('%d' % i, sep='', end=', '),
  for ind in order_centroids[i, :20]:
    print(terms[ind], sep='', end=', ')
  print('')

# %%
# Check the size of each cluster
df.k_means.value_counts(ascending=False)
# Out:
# 2    465
# 9    262
# 3    152
# 5    148
# 7    121
# 6    114
# 0    101
# 4     87
# 1     47
# 8     41
# Name: k_means, dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'description', 'category_name', 'thumbnail', 'url',
#        'category_title_description', 'Text', 'k_means'],
#       dtype='object')

# %%
# Save the dataframe to .csv for later use
df[['title', 'description', 'category_name', 'thumbnail', 'url', 'category_title_description', 'Text', 'k_means']].to_csv('../data/abc.csv')
